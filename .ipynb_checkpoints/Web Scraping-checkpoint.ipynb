# %% [markdown]
# ## Lab 1.

# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite')
# Out:
# [<cite class="title">81 Million Votes, My Ass</cite>]

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > em')
# Out:
# [<em class="artist">The Truth Bombers &amp; Kari Lake</em>]

# %%
title = soup.select

# %%
title = []
artist = []

num_iter = len(soup.select('div.chart-content.col-xs-12.col-sm-8 > p'))

title_list = soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')
artist_list = soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em')


for i in range(num_iter):
    title.append(title_list[i].get_text())
    artist.append(artist_list[i].get_text())
print(title)
print(artist)
# Out:
# ['81 Million Votes, My Ass', 'Fast Car', 'Take Two', 'Last Night', 'Need A Favor', 'Save Me (with Lainey Wilson)', 'Flowers', 'Son', 'Let Me In', 'Thank God I Do', 'Calm Down', 'Bust a Move', 'Son Of A Sinner', 'Rode Hard', 'Thinkin’ Bout Me', 'Funky Cold Medina', 'Dance The Night', 'Area Codes', 'Pound Town 2', 'TRUSTFALL', 'Thicc As Thieves', 'Stand By Me (feat. Morgan Wallen)', 'All My Life (feat. J. Cole)', 'Cruel Summer', 'Wild Thing', 'Thank God', 'Love You Anyway', 'Favorite Song', 'Eyes Closed', 'Dancin’ In The Country', 'Thought You Should Know', 'Religiously', 'Heart Like A Truck', 'Karma', 'VULGAR', 'Anti-Hero', "Something in the Orange (Z&E's Version)", 'Heaven', 'Tennessee Orange', 'If You Were Mine', 'One Thing At A Time', 'Popular', 'Rock and A Hard Place', 'Am I Dreaming', 'Next Thing You Know', 'Mourning', 'Praise You Anywhere', 'Bury Me in Georgia (Single Edit)', 'Watermelon Moonshine', 'Daylight', 'To the Bar', 'Can She Have This Dance', 'Waffle House', 'Chemical',
# ...

# %%
songs = pd.DataFrame({"title":title,
                       "artist":artist
                      })

# %%
songs
# Out:
#                        title                         artist
# 0   81 Million Votes, My Ass  The Truth Bombers & Kari Lake
# 1                   Fast Car                     Luke Combs
# 2                   Take Two                            BTS
# 3                 Last Night                  Morgan Wallen
# 4               Need A Favor                     Jelly Roll
# ..                       ...                            ...
# 95                     HAPPY                             NF
# 96      How Do I Say Goodbye                     Dean Lewis
# 97        Your Heart Or Mine                      Jon Pardi
# 98   Cowgirls (feat. ERNEST)                  Morgan Wallen
# 99            'Til You Can't                   Cody Johnson
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Lab 2.

# %%
url1 = "https://www.billboard.com/charts/greatest-hot-100-singles/"

# %%
response1 = requests.get(url1)
response1.status_code
# Out:
# 200

# %%
soup1 = BeautifulSoup(response1.content, "html.parser")

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 6]>
# <html id="ie6" lang="en-US">
# <![endif]-->
# <!--[if IE 7]>
# <html id="ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html id="ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 6) | !(IE 7) | !(IE 8) ]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <!-- Add to home screen for iOS -->
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/app/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <!-- Tile icons for Windows -->
# <meta content="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/app/browserconfig.xml" name="msapplication-config"/>
# ...

# %%
soup1.select("div.chart-results-list.\/\/.u-padding-b-250.u-max-width-830.lrv-u-margin-lr-auto > div:nth-child(1) > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.lrv-u-border-color-grey-light.lrv-u-padding-l-2.lrv-u-padding-r-1.lrv-u-padding-l-1\@mobile-max h3")
# Out:
# [<h3 class="c-title a-font-primary-bold-xxl a-font-primary-bold-l@mobile-max u-font-size-45@desktop" id="title-of-a-story">
#
#
#
#
#  					Blinding Lights
#
#  </h3>]

# %%
artist_list1 = soup1.select("div.chart-results-list.\/\/.u-padding-b-250.u-max-width-830.lrv-u-margin-lr-auto > div:nth-child(2) > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.lrv-u-border-color-grey-light.lrv-u-padding-l-2.lrv-u-padding-r-1.lrv-u-padding-l-1\@mobile-max > span")

# %%
title_list1 = soup1.select("div.chart-results-list.\/\/.u-padding-b-250.u-max-width-830.lrv-u-margin-lr-auto > div:nth-child(1) > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.lrv-u-border-color-grey-light.lrv-u-padding-l-2.lrv-u-padding-r-1.lrv-u-padding-l-1\@mobile-max h3")

# %%
titles1 = []
artist1 = []

num_iter = len(artist_list1)

for i in range(num_iter):
    titles1.append(title_list1[i].get_text(strip=True))
    artist1.append(artist_list1[i].get_text(strip=True))

print(titles1)
print(artist1)
# Out:
# ['Blinding Lights']
# ['Chubby Checker']
